# %% [markdown]
# # 🛡️ NPL-Sentinel

# %% [markdown]
# ![NPL Sentinel Banner](https://github.com/lucianoayres/npl-sentinel/raw/main/images/sentinel_banner.png)

# %% [markdown]
# ## Análise de Sentimento em Avaliações de Produtos
#
# - #### Curso: Pós-Graduação em Deep Learning (CIn - UFPE)
# - ##### Disciplina: Processamento de Linguagem Natural
#   - ##### Professor: Luciano Barbosa
#
# - ##### 👥 Grupo:
#   - Paloma Corrêa Alves (pca2@cin.ufpe.br)
#   - Luciano Ayres Farias de Carvalho (lafc@cin.ufpe.br)
#
# ## 📖 Sobre o Projeto
#
# ### 🔍 Visão Geral
# O **NPL-Sentinel** é um projeto que explora **Processamento de Linguagem Natural (PLN)** para analisar sentimentos expressos em avaliações de consumidores sobre um produto fictício: um **smartphone**. 📱✨
#
# ### 🎯 Objetivo
# Este projeto tem como **meta principal** identificar a polaridade dos sentimentos (😊 Positivo, 😐 Neutro, 😞 Negativo) contidos nas avaliações dos consumidores. Além disso:
# - **📈 Correlacionar** a polaridade dos sentimentos com as notas atribuídas pelos consumidores, validando a precisão do modelo.
# - **🔍 Realizar análises exploratórias** para identificar padrões nas avaliações, destacando os aspectos mais comentados em avaliações positivas e negativas.
#
# ### 🤖 Modelos Utilizados
# 🔹 **SVM + Bag of Words (BoW)**
# 🔹 **SVM + Embeddings**
# 🔹 **BERT**
# 🔹 **In-Context Learning**: OpenAI
# 🔹 **In-Content Learning**: Google Gemini
#
# ### 📑 Sobre os Dados
# Os dados utilizados consistem em:
# - **💬 review:** Comentário livre do consumidor sobre o produto (smartphone).
# - **⭐ rating:** Nota (1 a 5) atribuída pelo consumidor, indicando sua satisfação com o smartphone.
#
# ### 💡 Por que NPL-Sentinel?
# Porque a ideia é ir além da análise básica, atuando como um "sentinela" que monitora tendências, sentimentos e insights valiosos diretamente das opiniões dos consumidores. 🚀

# %% [markdown]
# # 1. Carregamento dos Dados

# %%
import pandas as pd

# URL do arquivo CSV remoto
url = "https://raw.githubusercontent.com/lucianoayres/npl-sentinel/refs/heads/main/data/reviews.csv"

# Carrega o arquivo CSV em um DataFrame do pandas
df = pd.read_csv(url)

# Salva o DataFrame localmente no Google Colab
df.to_csv("reviews.csv", index=False)

# Exibe as primeiras linhas do DataFrame (opcional)
print(df.head())
# Out:
#                                               review  rating
# 0  O produto é ok, nada demais. não se destaca no...       3
# 1        Decepcionante, não atendeu às expectativas.       1
# 2  Não tenho muito o que comentar, cumpre o que p...       2
# 3        Decepcionante, não funcionou como esperado.       2
# 4                   É razoável, não é nada especial.       2

# %%
# Exibe tipos de dados de cada coluna
print("\nTipos de dados de cada coluna:")
df.info()
# Out:
# Tipos de dados de cada coluna:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195 entries, 0 to 1194
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  1195 non-null   object
#  1   rating  1195 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 18.8+ KB

# %%
# Imprime um describe detalhado, incluindo todas as colunas
print("\nDescrição detalhada dos dados:")
print(df.describe(include='all'))
# Out:
# Descrição detalhada dos dados:
#                                             review       rating
# count                                         1195  1195.000000
# unique                                        1107          NaN
# top     Cumpre o que promete, mas nada além disso.          NaN
# freq                                             3          NaN
# mean                                           NaN     3.531381
# std                                            NaN     1.438165
# min                                            NaN     1.000000
# 25%                                            NaN     2.000000
# 50%                                            NaN     4.000000
# 75%                                            NaN     5.000000
# max                                            NaN     5.000000

# %%
# Estatísticas descritivas para variáveis categóricas
print("\nEstatísticas descritivas para variáveis categóricas:")
print(df.describe(include=['object']))
# Out:
# Estatísticas descritivas para variáveis categóricas:
#                                             review
# count                                         1195
# unique                                        1107
# top     Cumpre o que promete, mas nada além disso.
# freq                                             3

# %% [markdown]
# # 2. Pré-processamento dos Dados
#
# Uso do `nltk` para tokenização, remoção de stopwords e outras técnicas de limpeza.

# %%
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords
import string

# Faz o download das stopwords
nltk.download("stopwords")
stop_words = stopwords.words("portuguese")

# Função para pré-processar o texto
def preprocess_text(text):
    text = text.lower()  # Converte para minúsculas
    text = text.translate(str.maketrans('', '', string.punctuation))  # Remove pontuação
    text = "".join([char for char in text if char.isalnum() or char.isspace()])  # Remove caracteres não alfanuméricos
    tokens = [word for word in text.split() if word not in stop_words]  # Remove stopwords
    return " ".join(tokens)  # Junta os tokens de volta em uma string

# Aplica a função de pré-processamento à coluna 'review'
df["clean_review"] = df["review"].apply(preprocess_text)

# Função para converter notas em rótulos de sentimento
def convert_to_sentiment(rating):
    if rating >= 4:
        return "positivo"
    elif rating <= 2:
        return "negativo"
    else:
        return "neutro"

# Aplica a função de conversão à coluna 'rating'
df["sentiment"] = df["rating"].apply(convert_to_sentiment)

# Verifica e remove linhas com review ou rating vazio
empty_reviews = df["review"].isnull() | (df["review"].str.strip() == "")
empty_ratings = df["rating"].isnull()
df = df[~(empty_reviews | empty_ratings)]

# Exibe a quantidade de reviews e ratings vazios removidos
print("\nItens Removidos:")
print("Reviews vazios:", df["review"].isnull().sum() + (df["review"].str.strip() == "").sum())
print("Ratings vazios:", df["rating"].isnull().sum())
# Out:
# Itens Removidos:
# Reviews vazios: 0
# Ratings vazios: 0
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # 3. Análise Descritiva

# %% [markdown]
# ## 3.1. Distribuição das Notas (rating)

# %%
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import seaborn as sns

# Análise da Distribuição das Notas
plt.figure(figsize=(8, 6))
ax = sns.countplot(x='rating', data=df, hue='rating', palette='pastel', legend=False)  # Changes here

# Adiciona os totais em cima das barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.title('Distribuição das Notas')
plt.xlabel('Nota')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Resultados Totais da Distribuição das Notas

# %%
# Imprime os totais para cada nota
print("\nResultados Totais da Distribuição das Notas:")
rating_counts = df['rating'].value_counts().sort_index()
for rating, count in rating_counts.items():
    print(f"Nota {rating}: {count} avaliações")
# Out:
# Resultados Totais da Distribuição das Notas:
# Nota 1: 153 avaliações
# Nota 2: 165 avaliações
# Nota 3: 233 avaliações
# Nota 4: 182 avaliações
# Nota 5: 462 avaliações

# %% [markdown]
# ## 3.2. Histograma do Comprimento das Avaliações (review)

# %%
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(8, 6))
plt.hist(df['review'].str.len(), bins=50)
plt.title('Histograma do Comprimento das Avaliações')
plt.xlabel('Comprimento da Avaliação (caracteres)')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Estatísticas do Comprimento das Avaliações

# %%
import pandas as pd
import numpy as np

review_lengths = df['review'].str.len()
hist, bin_edges = np.histogram(review_lengths, bins=50) # Calculate hist and bin_edges

# Cria um DataFrame para estatísticas resumidas
summary_data = {
    "Métrica": ["Total de Avaliações", "Comprimento Médio", "Comprimento Mínimo", "Comprimento Máximo", "Desvio Padrão"],
    "Valor": [
        len(review_lengths),
        f"{review_lengths.mean():.2f} caracteres",
        f"{review_lengths.min()} caracteres",
        f"{review_lengths.max()} caracteres",
        f"{review_lengths.std():.2f} caracteres",
    ],
}
summary_df = pd.DataFrame(summary_data)

# Cria um DataFrame para a distribuição de comprimentos
distribution_data = {
    "Intervalo de Comprimento": [f"{bin_edges[i]:.0f}-{bin_edges[i+1]:.0f}" for i in range(len(hist))],
    "Frequência (Avaliações)": hist,
}
distribution_df = pd.DataFrame(distribution_data)

# Exibe as tabelas
print("Estatísticas Resumidas:")
print(summary_df.to_string(index=False))  # index=False para ocultar os números das linhas

print("\nDistribuição de Comprimentos:")
print(distribution_df.to_string(index=False))
# Out:
# Estatísticas Resumidas:
#             Métrica            Valor
# Total de Avaliações             1195
#   Comprimento Médio 51.96 caracteres
#  Comprimento Mínimo    10 caracteres
#  Comprimento Máximo   101 caracteres
#       Desvio Padrão 10.76 caracteres
#
# Distribuição de Comprimentos:
# Intervalo de Comprimento  Frequência (Avaliações)
#                    10-12                        1
#                    12-14                        0
#                    14-15                        0
#                    15-17                        0
#                    17-19                        2
#                    19-21                        2
#                    21-23                        6
#                    23-25                        2
#                    25-26                        7
#                    26-28                        6
#                    28-30                        2
#                    30-32                        7
#                    32-34                       13
#                    34-35                       15
#                    35-37                       20
#                    37-39                       27
#                    39-41                       22
#                    41-43                       77
#                    43-45                       62
#                    45-46                       70
#                    46-48                      102
#                    48-50                       94
#                    50-52                       43
#                    52-54                       90
#                    54-56                      110
#                    56-57                       93
#                    57-59                       68
#                    59-61                       32
#                    61-63                       58
#                    63-65                       38
#                    65-66                       38
#                    66-68                       24
#                    68-70                       12
#                    70-72                        9
#                    72-74                       11
#                    74-76                       10
#                    76-77                        6
#                    77-79                        6
#                    79-81                        0
#                    81-83                        1
#                    83-85                        0
#                    85-86                        2
#                    86-88                        1
#                    88-90                        0
#                    90-92                        0
#                    92-94                        1
#                    94-96                        2
#                    96-97                        1
#                    97-99                        1
#                   99-101                        1

# %% [markdown]
# ## 3.3. Nuvem de Palavras

# %%
from wordcloud import WordCloud
text = ' '.join(df['clean_review'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nuvem de Palavras')
plt.show()

# %% [markdown]
# ### Resultados para a Nuvem de Palavras

# %%
import pandas as pd

# Obter as palavras mais frequentes e suas frequências
word_freq = wordcloud.words_

# Criar um DataFrame para armazenar as palavras e frequências
top_words_df = pd.DataFrame(list(word_freq.items())[:10], columns=['Palavra', 'Frequência'])

# Exibir o DataFrame como uma tabela
print("Top 10 palavras mais frequentes:")
print(top_words_df.to_string(index=False))
# Out:
# Top 10 palavras mais frequentes:
#    Palavra  Frequência
#    produto    1.000000
#  qualidade    0.471154
#  excelente    0.403846
#     gostei    0.350962
#  recomendo    0.274038
# desempenho    0.245192
#      ótimo    0.230769
#        bom    0.225962
#        uso    0.211538
#        bem    0.206731

# %% [markdown]
# ## 3.4 Frequência das Entidades (review)

# %%
# Faz o Download do Modelo de Linguagem PT-BR
# !python -m spacy download pt_core_news_md

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from collections import Counter
import spacy

import plotly.express as px

# Carregamento do modelo de linguagem do spaCy
nlp = spacy.load('pt_core_news_md')

# Pré-processamento com spaCy
def preprocess(text):
    doc = nlp(text)
    tokens = [
        token.lemma_.lower() for token in doc
        if not token.is_stop and not token.is_punct and not token.like_num
    ]
    return ' '.join(tokens)

df['clean_review'] = df['review'].astype(str).apply(preprocess)

# Análise de Entidades Nomeadas com spaCy
def extract_entities(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ in ['ORG', 'PERSON', 'LOC', 'PRODUCT']]

df['entities'] = df['review'].astype(str).apply(extract_entities)

# Contagem das entidades mais frequentes
all_entities = [entity for sublist in df['entities'] for entity in sublist]
entity_freq = Counter(all_entities).most_common(20)
# Out:
# Collecting pt-core-news-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_md-3.7.0/pt_core_news_md-3.7.0-py3-none-any.whl (42.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-md==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.1.2)
# Installing collected packages: pt-core-news-md
# Successfully installed pt-core-news-md-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Visualização: Frequência das Entidades
entities_df = pd.DataFrame(entity_freq, columns=['Entidade', 'Frequência'])
plt.figure(figsize=(12, 8))
sns.barplot(x='Frequência', y='Entidade', data=entities_df, palette='magma', hue='Entidade', dodge=False)  # Modified line
plt.title('Top 20 Entidades Nomeadas Mais Frequentes')
plt.xlabel('Frequência')
plt.ylabel('Entidade')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.5 Análise de N-grams (Bigrams e Trigrams com TF-IDF)

# %%
# Análise de N-grams Avançada (Bigrams e Trigrams com TF-IDF)
def get_top_ngrams(corpus, n=None, top=None):
    vec = TfidfVectorizer(ngram_range=(n, n)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:top]

top_bigrams = get_top_ngrams(df['clean_review'], n=2, top=10)
top_trigrams = get_top_ngrams(df['clean_review'], n=3, top=10)

# Visualização de Bigrams
bigrams_df = pd.DataFrame(top_bigrams, columns=['Bigram', 'TF-IDF'])
plt.figure(figsize=(10, 6))
sns.barplot(x='TF-IDF', y='Bigram', data=bigrams_df, hue='Bigram', palette='coolwarm', dodge=False, legend=False) # Modified line
plt.title('Top 10 Bigrams com Maior TF-IDF')
plt.xlabel('TF-IDF')
plt.ylabel('Bigram')
plt.tight_layout()
plt.show()

# %%
# Visualização de Trigrams
trigrams_df = pd.DataFrame(top_trigrams, columns=['Trigram', 'TF-IDF'])
plt.figure(figsize=(10, 6))
sns.barplot(x='TF-IDF', y='Trigram', data=trigrams_df, hue='Trigram', palette='coolwarm', dodge=False, legend=False)
plt.title('Top 10 Trigrams com Maior TF-IDF')
plt.xlabel('TF-IDF')
plt.ylabel('Trigram')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.6 Análise do Comprimento da Avaliação vs. Nota com Regressão

# %%
# Análise do Comprimento da Avaliação vs. Nota com Regressão
df['review_length'] = df['review'].astype(str).apply(len)

plt.figure(figsize=(10, 6))
sns.regplot(x='review_length', y='rating', data=df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Relação entre Comprimento da Avaliação e Nota')
plt.xlabel('Comprimento da Avaliação (caracteres)')
plt.ylabel('Nota')
plt.show()

# %% [markdown]
# ### Correlação entre Comprimento da Avaliação e Nota

# %%
# Calcular e imprimir a correlação
correlation = df['review_length'].corr(df['rating'])
print("-" * 50)
print(f"Coeficiente de correlação de Pearson: {correlation:.2f}")
print("-" * 50)
# Out:
# --------------------------------------------------
# Coeficiente de correlação de Pearson: 0.07
# --------------------------------------------------

# %% [markdown]
# # 4. Treinamento de Classificadores
#
# ## 4.1 SVM + Bag of Words (BoW)

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, classification_report

# Divide o dataset
X_train, X_test, y_train, y_test = train_test_split(df["clean_review"], df["rating"], test_size=0.2, random_state=42)

# Pipeline para SVM com Bag of Words
pipeline_bow = Pipeline([
    ("vectorizer", CountVectorizer()),
    ("classifier", SVC())
])

# Treinamento
pipeline_bow.fit(X_train, y_train)
y_pred_bow = pipeline_bow.predict(X_test)

# %% [markdown]
# ### Avaliação dos Resultados para o SVM + Bag of Words (BoW)

# %%
# Avaliação
print("SVM + Bag of Words")
print(classification_report(y_test, y_pred_bow))

# Calcula a acurácia e F1 score
accuracy_bow = accuracy_score(y_test, y_pred_bow)
f1_bow = f1_score(y_test, y_pred_bow, average='weighted')

print(f"Accuracy: {accuracy_bow}")
print(f"F1-score: {f1_bow}")
# Out:
# SVM + Bag of Words
#               precision    recall  f1-score   support
#
#            1       0.56      0.50      0.53        28
#            2       0.32      0.25      0.28        28
#            3       0.48      0.51      0.50        49
#            4       0.50      0.10      0.17        48
#            5       0.57      0.86      0.69        86
#
#     accuracy                           0.52       239
#    macro avg       0.49      0.44      0.43       239
# weighted avg       0.51      0.52      0.48       239
#
# Accuracy: 0.5230125523012552
# F1-score: 0.4773709898228217

# %% [markdown]
# ### Matriz de Confusão para o SVM + Bag of Words (BoW)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Function to create a confusion matrix heatmap
def plot_confusion_matrix(y_true, y_pred, title="Confusion Matrix"):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=np.unique(y_true), yticklabels=np.unique(y_true))
    plt.title(title)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

# Plot the confusion matrix for the BoW model
plot_confusion_matrix(y_test, y_pred_bow, title="Confusion Matrix - SVM + Bag of Words")

# %% [markdown]
# ## 4.2 SVM + Embeddings
#
# Uso de `spacy` para converter as avaliações em embeddings e treinar o SVM com esses vetores.

# %%
# Faz o Download do Modelo de Linguagem PT-BR
# !python -m spacy download pt_core_news_md

import spacy
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# Usa embeddings do spaCy
nlp = spacy.load("pt_core_news_md")
X_train_embedded = [nlp(text).vector for text in X_train]
X_test_embedded = [nlp(text).vector for text in X_test]

# Normaliza os embeddings
scaler = StandardScaler()
X_train_embedded = scaler.fit_transform(X_train_embedded)
X_test_embedded = scaler.transform(X_test_embedded)

# Treina o SVM com embeddings
svm_embedding = SVC()
svm_embedding.fit(X_train_embedded, y_train)
y_pred_embed = svm_embedding.predict(X_test_embedded)
# Out:
# Collecting pt-core-news-md==3.7.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/pt_core_news_md-3.7.0/pt_core_news_md-3.7.0-py3-none-any.whl (42.4 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-md==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %% [markdown]
# ### Avaliação dos Resultados para o SVM + Embeddings

# %%
# Avaliação
print("SVM + Embeddings")
print(classification_report(y_test, y_pred_embed))

# Calcula a acurácia e F1 score
accuracy_embed = accuracy_score(y_test, y_pred_embed)
f1_embed = f1_score(y_test, y_pred_embed, average='weighted')

print(f"Accuracy: {accuracy_embed}")
print(f"F1-score: {f1_embed}")
# Out:
# SVM + Embeddings
#               precision    recall  f1-score   support
#
#            1       0.57      0.57      0.57        28
#            2       0.33      0.25      0.29        28
#            3       0.51      0.43      0.47        49
#            4       0.45      0.10      0.17        48
#            5       0.58      0.93      0.71        86
#
#     accuracy                           0.54       239
#    macro avg       0.49      0.46      0.44       239
# weighted avg       0.51      0.54      0.49       239
#
# Accuracy: 0.5397489539748954
# F1-score: 0.48715829002333505

# %% [markdown]
# ### Matriz de Confusão para o SVM + Embedding

# %%
plot_confusion_matrix(y_test, y_pred_embed, title="Confusion Matrix - SVM + Embeddings")

# %% [markdown]
# ## 4.3 BERT para Classificação
#
# Usando `transformers` para fine-tuning de um modelo BERT para classificação de sentimentos.

# %%
from transformers import BertTokenizer, TFBertForSequenceClassification, AdamWeightDecay

import tensorflow as tf

# Restringe o TensorFlow para usar apenas a CPU
tf.config.set_visible_devices([], 'GPU')

# Prepara o modelo BERT
tokenizer = BertTokenizer.from_pretrained("neuralmind/bert-base-portuguese-cased")
model = TFBertForSequenceClassification.from_pretrained("neuralmind/bert-base-portuguese-cased", num_labels=5)

# Tokeniza os dados
X_train_tokens = tokenizer(list(X_train), padding=True, truncation=True, return_tensors="tf")
X_test_tokens = tokenizer(list(X_test), padding=True, truncation=True, return_tensors="tf")

# Define o otimizador e a função de perda
optimizer = AdamWeightDecay(learning_rate=3e-5)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metrics = tf.keras.metrics.SparseCategoricalAccuracy()

# Loop de treinamento personalizado
def train_step(inputs, targets):
    # Subtrai 1 dos targets para ajustar o intervalo para 0-4
    targets = targets - 1
    with tf.GradientTape() as tape:
        predictions = model(inputs)
        loss = loss_fn(targets, predictions.logits)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    metrics.update_state(targets, predictions.logits)
    return loss, metrics.result()

# Loop de Treinamento
epochs = 3
batch_size = 8
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    for i in range(0, len(X_train), batch_size):
        batch_inputs = {k: v[i:i + batch_size] for k, v in X_train_tokens.data.items()}
        batch_targets = y_train[i:i + batch_size]
        # Subtraindo 1 dos targets para ajustar o intervalo para 0-4
        loss, accuracy = train_step(batch_inputs, batch_targets)
        print(f"Batch {i // batch_size + 1}: Loss = {loss:.4f}, Accuracy = {accuracy:.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/43.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/210k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/647 [00:00<?, ?B/s]
# tf_model.h5:   0%|          | 0.00/529M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-base-portuguese-cased and are newly initialized: ['classifier', 'bert/pooler/dense/bias:0', 'bert/pooler/dense/kernel:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Epoch 1/3
# Batch 1: Loss = 1.5784, Accuracy = 0.2500
# Batch 2: Loss = 1.5508, Accuracy = 0.3125
# Batch 3: Loss = 1.5125, Accuracy = 0.3333
# Batch 4: Loss = 1.4026, Accuracy = 0.4062
# Batch 5: Loss = 1.5488, Accuracy = 0.3750
# Batch 6: Loss = 1.6425, Accuracy = 0.3542
# Batch 7: Loss = 1.7565, Accuracy = 0.3214
# Batch 8: Loss = 1.6000, Accuracy = 0.3125
# Batch 9: Loss = 1.4710, Accuracy = 0.3194
# Batch 10: Loss = 1.6825, Accuracy = 0.3000
# Batch 11: Loss = 1.3954, Accuracy = 0.3182
# Batch 12: Loss = 1.5982, Accuracy = 0.3021
# Batch 13: Loss = 1.4434, Accuracy = 0.3173
# Batch 14: Loss = 1.4695, Accuracy = 0.3214
# Batch 15: Loss = 1.3132, Accuracy = 0.3417
# Batch 16: Loss = 1.3569, Accuracy = 0.3516
# Batch 17: Loss = 1.3701, Accuracy = 0.3676
# Batch 18: Loss = 1.3846, Accuracy = 0.3750
# Batch 19: Loss = 1.7077, Accuracy = 0.3618
# Batch 20: Loss = 1.4552, Accuracy = 0.3625
# Batch 21: Loss = 1.8172, Accuracy = 0.3512
# Batch 22: Loss = 1.4886, Accuracy = 0.3523
# Batch 23: Loss = 1.6257, Accuracy = 0.3478
# Batch 24: Loss = 1.4879, Accuracy = 0.3490
# Batch 25: Loss = 1.5303, Accuracy = 0.3450
# Batch 26: Loss = 1.2948, Accuracy = 0.3510
# Batch 27: Loss = 1.3152, Accuracy = 0.3519
# Batch 28: Loss = 1.3948, Accuracy = 0.3527
# Batch 29: Loss = 1.4166, Accuracy = 0.3534
# Batch 30: Loss = 1.4134, Accuracy = 0.3500
# Batch 31: Loss = 1.3379, Accuracy = 0.3508
# Batch 32: Loss = 1.0517, Accuracy = 0.3594
# Batch 33: Loss = 1.0963, Accuracy = 0.3712
# Batch 34: Loss = 1.2547, Accuracy = 0.3713
# Batch 35: Loss = 1.3204, Accuracy = 0.3786
# Batch 36: Loss = 1.4723, Accuracy = 0.3785
# Batch 37: Loss = 1.0535, Accuracy = 0.3851
# Batch 38: Loss = 0.9353, Accuracy = 0.3947
# Batch 39: Loss = 1.1904, Accuracy = 0.4006
# Batch 40: Loss = 1.2719, Accuracy = 0.4062
# Batch 41: Loss = 1.1969, Accuracy = 0.4055
# Batch 42: Loss = 1.2718, Accuracy = 0.4107
# Batch 43: Loss = 1.6710, Accuracy = 0.4070
# Batch 44: Loss = 1.0219, Accuracy = 0.4119
# Batch 45: Loss = 1.0926, Accuracy = 0.4139
# Batch 46: Loss = 1.3048, Accuracy = 0.4130
# Batch 47: Loss = 1.6700, Accuracy = 0.4096
# Batch 48: Loss = 1.2628, Accuracy = 0.4115
# Batch 49: Loss = 1.4621, Accuracy = 0.4056
# Batch 50: Loss = 1.3455, Accuracy = 0.4025
# Batch 51: Loss = 1.2990, Accuracy = 0.4044
# Batch 52: Loss = 1.3410, Accuracy = 0.4014
# Batch 53: Loss = 1.3860, Accuracy = 0.4009
# Batch 54: Loss = 1.2904, Accuracy = 0.4005
# Batch 55: Loss = 1.3960, Accuracy = 0.3977
# Batch 56: Loss = 1.2346, Accuracy = 0.3973
# Batch 57: Loss = 1.3323, Accuracy = 0.3991
# Batch 58: Loss = 1.2383, Accuracy = 0.4009
# Batch 59: Loss = 1.4651, Accuracy = 0.4004
# Batch 60: Loss = 1.0353, Accuracy = 0.4042
# Batch 61: Loss = 1.1874, Accuracy = 0.4057
# Batch 62: Loss = 1.1070, Accuracy = 0.4113
# Batch 63: Loss = 1.2886, Accuracy = 0.4107
# Batch 64: Loss = 1.3051, Accuracy = 0.4121
# Batch 65: Loss = 0.6714, Accuracy = 0.4192
# Batch 66: Loss = 1.0800, Accuracy = 0.4205
# Batch 67: Loss = 1.5086, Accuracy = 0.4216
# Batch 68: Loss = 0.9270, Accuracy = 0.4246
# Batch 69: Loss = 1.3622, Accuracy = 0.4257
# Batch 70: Loss = 0.9288, Accuracy = 0.4286
# Batch 71: Loss = 1.6886, Accuracy = 0.4278
# Batch 72: Loss = 1.1729, Accuracy = 0.4306
# Batch 73: Loss = 1.3803, Accuracy = 0.4315
# Batch 74: Loss = 1.3556, Accuracy = 0.4341
# Batch 75: Loss = 1.0672, Accuracy = 0.4350
# Batch 76: Loss = 0.9502, Accuracy = 0.4375
# Batch 77: Loss = 1.1852, Accuracy = 0.4383
# Batch 78: Loss = 0.9430, Accuracy = 0.4423
# Batch 79: Loss = 1.1196, Accuracy = 0.4462
# Batch 80: Loss = 1.1084, Accuracy = 0.4453
# Batch 81: Loss = 1.2608, Accuracy = 0.4429
# Batch 82: Loss = 1.1695, Accuracy = 0.4436
# Batch 83: Loss = 0.9011, Accuracy = 0.4488
# Batch 84: Loss = 0.8320, Accuracy = 0.4509
# Batch 85: Loss = 1.1932, Accuracy = 0.4500
# Batch 86: Loss = 0.7137, Accuracy = 0.4564
# Batch 87: Loss = 1.2356, Accuracy = 0.4569
# Batch 88: Loss = 0.8774, Accuracy = 0.4602
# Batch 89: Loss = 1.0620, Accuracy = 0.4621
# Batch 90: Loss = 0.8373, Accuracy = 0.4653
# Batch 91: Loss = 0.7680, Accuracy = 0.4684
# Batch 92: Loss = 1.3213, Accuracy = 0.4660
# Batch 93: Loss = 0.9196, Accuracy = 0.4664
# Batch 94: Loss = 1.0242, Accuracy = 0.4681
# Batch 95: Loss = 0.8190, Accuracy = 0.4711
# Batch 96: Loss = 1.2837, Accuracy = 0.4714
# Batch 97: Loss = 0.8639, Accuracy = 0.4716
# Batch 98: Loss = 1.5948, Accuracy = 0.4681
# Batch 99: Loss = 0.9117, Accuracy = 0.4684
# Batch 100: Loss = 1.4786, Accuracy = 0.4688
# Batch 101: Loss = 0.6167, Accuracy = 0.4715
# Batch 102: Loss = 1.2298, Accuracy = 0.4730
# Batch 103: Loss = 0.7864, Accuracy = 0.4769
# Batch 104: Loss = 0.7640, Accuracy = 0.4796
# Batch 105: Loss = 0.6111, Accuracy = 0.4821
# Batch 106: Loss = 0.9927, Accuracy = 0.4835
# Batch 107: Loss = 1.4602, Accuracy = 0.4813
# Batch 108: Loss = 1.2886, Accuracy = 0.4815
# Batch 109: Loss = 0.8243, Accuracy = 0.4839
# Batch 110: Loss = 1.1579, Accuracy = 0.4841
# Batch 111: Loss = 1.5897, Accuracy = 0.4831
# Batch 112: Loss = 1.4567, Accuracy = 0.4821
# Batch 113: Loss = 0.7969, Accuracy = 0.4845
# Batch 114: Loss = 1.2555, Accuracy = 0.4846
# Batch 115: Loss = 1.1187, Accuracy = 0.4837
# Batch 116: Loss = 0.9728, Accuracy = 0.4838
# Batch 117: Loss = 0.7747, Accuracy = 0.4872
# Batch 118: Loss = 1.0963, Accuracy = 0.4894
# Batch 119: Loss = 0.8811, Accuracy = 0.4905
# Batch 120: Loss = 0.9251, Accuracy = 0.4916
# Epoch 2/3
# Batch 1: Loss = 0.6110, Accuracy = 0.4948
# Batch 2: Loss = 1.1716, Accuracy = 0.4938
# Batch 3: Loss = 0.9026, Accuracy = 0.4949
# Batch 4: Loss = 0.8125, Accuracy = 0.4970
# Batch 5: Loss = 0.9728, Accuracy = 0.4970
# Batch 6: Loss = 1.2625, Accuracy = 0.4970
# Batch 7: Loss = 1.3056, Accuracy = 0.4951
# Batch 8: Loss = 0.9175, Accuracy = 0.4971
# Batch 9: Loss = 1.1529, Accuracy = 0.4971
# Batch 10: Loss = 0.8993, Accuracy = 0.4990
# Batch 11: Loss = 0.5457, Accuracy = 0.5019
# Batch 12: Loss = 1.0445, Accuracy = 0.5019
# Batch 13: Loss = 1.0322, Accuracy = 0.5028
# Batch 14: Loss = 0.9258, Accuracy = 0.5037
# Batch 15: Loss = 0.7227, Accuracy = 0.5046
# Batch 16: Loss = 0.7431, Accuracy = 0.5065
# Batch 17: Loss = 1.1775, Accuracy = 0.5064
# Batch 18: Loss = 0.9199, Accuracy = 0.5082
# Batch 19: Loss = 1.6821, Accuracy = 0.5063
# Batch 20: Loss = 0.8904, Accuracy = 0.5081
# Batch 21: Loss = 1.4194, Accuracy = 0.5071
# Batch 22: Loss = 1.1817, Accuracy = 0.5080
# Batch 23: Loss = 0.8192, Accuracy = 0.5088
# Batch 24: Loss = 0.8617, Accuracy = 0.5096
# Batch 25: Loss = 0.9312, Accuracy = 0.5095
# Batch 26: Loss = 0.7756, Accuracy = 0.5112
# Batch 27: Loss = 0.7176, Accuracy = 0.5137
# Batch 28: Loss = 0.8902, Accuracy = 0.5144
# Batch 29: Loss = 0.7968, Accuracy = 0.5160
# Batch 30: Loss = 0.8786, Accuracy = 0.5159
# Batch 31: Loss = 1.2469, Accuracy = 0.5158
# Batch 32: Loss = 0.4463, Accuracy = 0.5190
# Batch 33: Loss = 0.9323, Accuracy = 0.5197
# Batch 34: Loss = 0.7003, Accuracy = 0.5212
# Batch 35: Loss = 0.6142, Accuracy = 0.5227
# Batch 36: Loss = 0.6607, Accuracy = 0.5249
# Batch 37: Loss = 0.4948, Accuracy = 0.5280
# Batch 38: Loss = 0.6168, Accuracy = 0.5294
# Batch 39: Loss = 0.7227, Accuracy = 0.5308
# Batch 40: Loss = 0.7131, Accuracy = 0.5329
# Batch 41: Loss = 0.8530, Accuracy = 0.5343
# Batch 42: Loss = 0.8559, Accuracy = 0.5364
# Batch 43: Loss = 1.2262, Accuracy = 0.5362
# Batch 44: Loss = 0.4656, Accuracy = 0.5375
# Batch 45: Loss = 1.1956, Accuracy = 0.5372
# Batch 46: Loss = 0.8629, Accuracy = 0.5378
# Batch 47: Loss = 0.8532, Accuracy = 0.5383
# Batch 48: Loss = 0.5371, Accuracy = 0.5403
# Batch 49: Loss = 0.9025, Accuracy = 0.5415
# Batch 50: Loss = 1.4399, Accuracy = 0.5398
# Batch 51: Loss = 1.2055, Accuracy = 0.5396
# Batch 52: Loss = 0.7943, Accuracy = 0.5408
# Batch 53: Loss = 0.9061, Accuracy = 0.5413
# Batch 54: Loss = 0.7003, Accuracy = 0.5425
# Batch 55: Loss = 0.4434, Accuracy = 0.5444
# Batch 56: Loss = 0.7313, Accuracy = 0.5449
# Batch 57: Loss = 1.0278, Accuracy = 0.5446
# Batch 58: Loss = 1.0594, Accuracy = 0.5444
# Batch 59: Loss = 0.6554, Accuracy = 0.5455
# Batch 60: Loss = 0.5782, Accuracy = 0.5474
# Batch 61: Loss = 0.6813, Accuracy = 0.5485
# Batch 62: Loss = 0.6061, Accuracy = 0.5496
# Batch 63: Loss = 0.9520, Accuracy = 0.5500
# Batch 64: Loss = 0.6724, Accuracy = 0.5511
# Batch 65: Loss = 0.5421, Accuracy = 0.5522
# Batch 66: Loss = 0.7166, Accuracy = 0.5532
# Batch 67: Loss = 1.0660, Accuracy = 0.5529
# Batch 68: Loss = 0.6595, Accuracy = 0.5540
# Batch 69: Loss = 0.5690, Accuracy = 0.5557
# Batch 70: Loss = 0.7185, Accuracy = 0.5567
# Batch 71: Loss = 0.6523, Accuracy = 0.5571
# Batch 72: Loss = 0.5451, Accuracy = 0.5581
# Batch 73: Loss = 0.7905, Accuracy = 0.5584
# Batch 74: Loss = 0.7480, Accuracy = 0.5594
# Batch 75: Loss = 0.5370, Accuracy = 0.5611
# Batch 76: Loss = 0.3687, Accuracy = 0.5633
# Batch 77: Loss = 0.8306, Accuracy = 0.5630
# Batch 78: Loss = 0.4007, Accuracy = 0.5646
# Batch 79: Loss = 0.7521, Accuracy = 0.5655
# Batch 80: Loss = 0.8382, Accuracy = 0.5658
# Batch 81: Loss = 0.7608, Accuracy = 0.5661
# Batch 82: Loss = 0.7476, Accuracy = 0.5664
# Batch 83: Loss = 0.6590, Accuracy = 0.5667
# Batch 84: Loss = 0.3086, Accuracy = 0.5682
# Batch 85: Loss = 0.7482, Accuracy = 0.5685
# Batch 86: Loss = 0.7859, Accuracy = 0.5700
# Batch 87: Loss = 0.7466, Accuracy = 0.5702
# Batch 88: Loss = 0.2919, Accuracy = 0.5717
# Batch 89: Loss = 0.5686, Accuracy = 0.5731
# Batch 90: Loss = 0.5692, Accuracy = 0.5746
# Batch 91: Loss = 0.6242, Accuracy = 0.5754
# Batch 92: Loss = 0.9076, Accuracy = 0.5751
# Batch 93: Loss = 0.5843, Accuracy = 0.5759
# Batch 94: Loss = 0.5197, Accuracy = 0.5773
# Batch 95: Loss = 0.7459, Accuracy = 0.5781
# Batch 96: Loss = 0.4600, Accuracy = 0.5789
# Batch 97: Loss = 0.5586, Accuracy = 0.5797
# Batch 98: Loss = 0.9039, Accuracy = 0.5793
# Batch 99: Loss = 0.3200, Accuracy = 0.5807
# Batch 100: Loss = 0.6685, Accuracy = 0.5814
# Batch 101: Loss = 0.3554, Accuracy = 0.5828
# Batch 102: Loss = 0.8565, Accuracy = 0.5835
# Batch 103: Loss = 0.4916, Accuracy = 0.5848
# Batch 104: Loss = 0.2387, Accuracy = 0.5867
# Batch 105: Loss = 0.3015, Accuracy = 0.5874
# Batch 106: Loss = 0.4541, Accuracy = 0.5887
# Batch 107: Loss = 1.4176, Accuracy = 0.5883
# Batch 108: Loss = 0.7835, Accuracy = 0.5885
# Batch 109: Loss = 0.3904, Accuracy = 0.5892
# Batch 110: Loss = 0.9042, Accuracy = 0.5893
# Batch 111: Loss = 0.8415, Accuracy = 0.5895
# Batch 112: Loss = 0.9679, Accuracy = 0.5896
# Batch 113: Loss = 0.6461, Accuracy = 0.5903
# Batch 114: Loss = 0.5978, Accuracy = 0.5910
# Batch 115: Loss = 0.8157, Accuracy = 0.5917
# Batch 116: Loss = 0.4104, Accuracy = 0.5929
# Batch 117: Loss = 0.5626, Accuracy = 0.5936
# Batch 118: Loss = 0.5770, Accuracy = 0.5942
# Batch 119: Loss = 0.5638, Accuracy = 0.5949
# Batch 120: Loss = 0.9562, Accuracy = 0.5952
# Epoch 3/3
# Batch 1: Loss = 0.1958, Accuracy = 0.5969
# Batch 2: Loss = 0.8550, Accuracy = 0.5970
# Batch 3: Loss = 0.5447, Accuracy = 0.5981
# Batch 4: Loss = 0.2328, Accuracy = 0.5998
# Batch 5: Loss = 0.4976, Accuracy = 0.6004
# Batch 6: Loss = 0.9409, Accuracy = 0.6005
# Batch 7: Loss = 0.6028, Accuracy = 0.6016
# Batch 8: Loss = 0.3289, Accuracy = 0.6032
# Batch 9: Loss = 0.4898, Accuracy = 0.6043
# Batch 10: Loss = 0.9033, Accuracy = 0.6049
# Batch 11: Loss = 0.1972, Accuracy = 0.6065
# Batch 12: Loss = 0.6740, Accuracy = 0.6071
# Batch 13: Loss = 1.1448, Accuracy = 0.6071
# Batch 14: Loss = 0.5316, Accuracy = 0.6077
# Batch 15: Loss = 0.6547, Accuracy = 0.6083
# Batch 16: Loss = 0.7296, Accuracy = 0.6088
# Batch 17: Loss = 0.3925, Accuracy = 0.6099
# Batch 18: Loss = 0.7729, Accuracy = 0.6099
# Batch 19: Loss = 1.6154, Accuracy = 0.6085
# Batch 20: Loss = 0.3761, Accuracy = 0.6096
# Batch 21: Loss = 1.0565, Accuracy = 0.6091
# Batch 22: Loss = 0.9451, Accuracy = 0.6097
# Batch 23: Loss = 0.5049, Accuracy = 0.6102
# Batch 24: Loss = 0.5370, Accuracy = 0.6112
# Batch 25: Loss = 0.4715, Accuracy = 0.6117
# Batch 26: Loss = 0.4822, Accuracy = 0.6127
# Batch 27: Loss = 0.2694, Accuracy = 0.6142
# Batch 28: Loss = 0.6273, Accuracy = 0.6147
# Batch 29: Loss = 0.3907, Accuracy = 0.6157
# Batch 30: Loss = 0.7273, Accuracy = 0.6162
# Batch 31: Loss = 0.7086, Accuracy = 0.6171
# Batch 32: Loss = 0.2163, Accuracy = 0.6185
# Batch 33: Loss = 0.2822, Accuracy = 0.6195
# Batch 34: Loss = 0.4499, Accuracy = 0.6204
# Batch 35: Loss = 0.3430, Accuracy = 0.6214
# Batch 36: Loss = 0.5514, Accuracy = 0.6218
# Batch 37: Loss = 0.5559, Accuracy = 0.6223
# Batch 38: Loss = 0.4374, Accuracy = 0.6232
# Batch 39: Loss = 0.5026, Accuracy = 0.6237
# Batch 40: Loss = 0.4906, Accuracy = 0.6246
# Batch 41: Loss = 0.3579, Accuracy = 0.6259
# Batch 42: Loss = 0.8511, Accuracy = 0.6263
# Batch 43: Loss = 0.6862, Accuracy = 0.6268
# Batch 44: Loss = 0.1913, Accuracy = 0.6281
# Batch 45: Loss = 1.2476, Accuracy = 0.6276
# Batch 46: Loss = 0.5056, Accuracy = 0.6281
# Batch 47: Loss = 0.5323, Accuracy = 0.6285
# Batch 48: Loss = 0.2966, Accuracy = 0.6294
# Batch 49: Loss = 0.5973, Accuracy = 0.6302
# Batch 50: Loss = 0.9458, Accuracy = 0.6302
# Batch 51: Loss = 0.4276, Accuracy = 0.6310
# Batch 52: Loss = 0.4466, Accuracy = 0.6319
# Batch 53: Loss = 0.3248, Accuracy = 0.6327
# Batch 54: Loss = 0.5263, Accuracy = 0.6331
# Batch 55: Loss = 0.2157, Accuracy = 0.6339
# Batch 56: Loss = 0.3767, Accuracy = 0.6343
# Batch 57: Loss = 0.6126, Accuracy = 0.6343
# Batch 58: Loss = 0.6980, Accuracy = 0.6343
# Batch 59: Loss = 0.5186, Accuracy = 0.6346
# Batch 60: Loss = 0.2077, Accuracy = 0.6359
# Batch 61: Loss = 1.0883, Accuracy = 0.6358
# Batch 62: Loss = 0.8642, Accuracy = 0.6354
# Batch 63: Loss = 0.3977, Accuracy = 0.6362
# Batch 64: Loss = 0.2875, Accuracy = 0.6370
# Batch 65: Loss = 0.4691, Accuracy = 0.6369
# Batch 66: Loss = 0.5375, Accuracy = 0.6377
# Batch 67: Loss = 0.7807, Accuracy = 0.6377
# Batch 68: Loss = 0.3775, Accuracy = 0.6384
# Batch 69: Loss = 0.3152, Accuracy = 0.6392
# Batch 70: Loss = 0.4458, Accuracy = 0.6400
# Batch 71: Loss = 0.1764, Accuracy = 0.6411
# Batch 72: Loss = 0.4188, Accuracy = 0.6419
# Batch 73: Loss = 0.4347, Accuracy = 0.6426
# Batch 74: Loss = 0.2931, Accuracy = 0.6434
# Batch 75: Loss = 0.2613, Accuracy = 0.6445
# Batch 76: Loss = 0.1910, Accuracy = 0.6456
# Batch 77: Loss = 0.5872, Accuracy = 0.6460
# Batch 78: Loss = 0.1438, Accuracy = 0.6471
# Batch 79: Loss = 0.2738, Accuracy = 0.6478
# Batch 80: Loss = 0.6891, Accuracy = 0.6481
# Batch 81: Loss = 1.0275, Accuracy = 0.6480
# Batch 82: Loss = 0.4939, Accuracy = 0.6484
# Batch 83: Loss = 0.3454, Accuracy = 0.6491
# Batch 84: Loss = 0.2970, Accuracy = 0.6498
# Batch 85: Loss = 0.2399, Accuracy = 0.6508
# Batch 86: Loss = 0.3174, Accuracy = 0.6515
# Batch 87: Loss = 0.5189, Accuracy = 0.6518
# Batch 88: Loss = 0.2201, Accuracy = 0.6525
# Batch 89: Loss = 0.1684, Accuracy = 0.6536
# Batch 90: Loss = 0.4386, Accuracy = 0.6539
# Batch 91: Loss = 0.4957, Accuracy = 0.6542
# Batch 92: Loss = 0.5144, Accuracy = 0.6545
# Batch 93: Loss = 0.3516, Accuracy = 0.6551
# Batch 94: Loss = 0.1332, Accuracy = 0.6562
# Batch 95: Loss = 0.3002, Accuracy = 0.6564
# Batch 96: Loss = 0.2272, Accuracy = 0.6571
# Batch 97: Loss = 0.5890, Accuracy = 0.6574
# Batch 98: Loss = 0.8324, Accuracy = 0.6573
# Batch 99: Loss = 0.1654, Accuracy = 0.6583
# Batch 100: Loss = 0.3282, Accuracy = 0.6586
# Batch 101: Loss = 0.3474, Accuracy = 0.6588
# Batch 102: Loss = 0.5068, Accuracy = 0.6595
# Batch 103: Loss = 0.3710, Accuracy = 0.6601
# Batch 104: Loss = 0.0934, Accuracy = 0.6611
# Batch 105: Loss = 0.1806, Accuracy = 0.6617
# Batch 106: Loss = 0.2260, Accuracy = 0.6627
# Batch 107: Loss = 1.1220, Accuracy = 0.6629
# Batch 108: Loss = 0.6926, Accuracy = 0.6635
# Batch 109: Loss = 0.1207, Accuracy = 0.6645
# Batch 110: Loss = 0.5185, Accuracy = 0.6648
# Batch 111: Loss = 0.4006, Accuracy = 0.6654
# Batch 112: Loss = 1.0601, Accuracy = 0.6652
# Batch 113: Loss = 0.4488, Accuracy = 0.6655
# Batch 114: Loss = 0.3172, Accuracy = 0.6661
# Batch 115: Loss = 0.2866, Accuracy = 0.6670
# Batch 116: Loss = 0.8245, Accuracy = 0.6669
# Batch 117: Loss = 0.2971, Accuracy = 0.6678
# Batch 118: Loss = 0.2764, Accuracy = 0.6688
# Batch 119: Loss = 0.3595, Accuracy = 0.6693
# Batch 120: Loss = 0.1896, Accuracy = 0.6698

# %% [markdown]
# ### Avaliação dos Resultados para o BERT

# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score

# Avaliação
predictions = model(X_test_tokens.data).logits

# Obtém os rótulos previstos a partir dos logits
predicted_labels = np.argmax(predictions, axis=1)

# Ajusta y_test para o intervalo 0-4 para avaliação (se necessário)
y_test_adjusted = y_test - 1

# Calcula as métricas
accuracy_bert = accuracy_score(y_test_adjusted, predicted_labels)
f1_bert = f1_score(y_test_adjusted, predicted_labels, average='weighted')
loss = loss_fn(y_test_adjusted, predictions) # Calcula a perda após o ajuste do y_test

print("\nBERT:")
print(f"Test Loss: {loss:.4f}") # Imprime a perda
print(f"Acurácia: {accuracy_bert:.4f}")
print(f"F1 Score: {f1_bert:.4f}")
# Out:
# BERT:
# Test Loss: 1.1060
# Acurácia: 0.6025
# F1 Score: 0.5803

# %% [markdown]
# ### Matriz de Confusão para o Resultado do BERT

# %%
# ### Matriz de Confusão para o Resultado do BERT
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Plot the confusion matrix for the BERT model
def plot_confusion_matrix(y_true, y_pred, title="Confusion Matrix"):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=np.unique(y_true), yticklabels=np.unique(y_true))
    plt.title(title)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

plot_confusion_matrix(y_test_adjusted, predicted_labels, title="Confusion Matrix - BERT")

# %% [markdown]
# # 5. Comparativo de Métricas e Resultados
#
# Resultado comparativo entre os três modelos (SVM + BoW, SVM + Embebddings e BERT).

# %%
# Cria um dicionário com os resultados
resultados = {
    "Modelo": ["SVM + Bag of Words", "SVM + Embeddings", "BERT"],
    "Acurácia": [accuracy_bow, accuracy_embed, accuracy_bert],
    "F1-Score": [f1_bow, f1_embed, f1_bert]
}

# Cria um DataFrame pandas com os resultados
df_resultados = pd.DataFrame(resultados)

# Exibe o DataFrame
print(df_resultados)
# Out:
#                Modelo  Acurácia  F1-Score
# 0  SVM + Bag of Words  0.523013  0.477371
# 1    SVM + Embeddings  0.539749  0.487158
# 2                BERT  0.602510  0.580334

# %% [markdown]
# ### Gráfico com Comparação de Desempenho dos Modelos

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))
df_resultados.plot(x="Modelo", y=["Acurácia", "F1-Score"], kind="bar", width=0.6, color=['skyblue', 'lightcoral'])
plt.title("Comparação de Desempenho dos Modelos")
plt.ylabel("Pontuação")
plt.xticks(rotation=0)
plt.legend(title="Métrica")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6. Classificação com In-Context Learning (Bônus)
#
# Utilizando LLM para realizar a classificação de sentimentos diretamente com poucas instruções, sem a necessidade de treinamento explícito.

# %%
# Define o temeplate do prompt
prompt_template = """
Você é um assistente de análise de sentimentos. Sua tarefa é classificar avaliações de produtos como "positivo", "negativo" ou "neutro".

Aqui está uma avaliação de um produto:
{review_text}

Classifique a avaliação acima como "Positivo", "Neutro" ou "Negativo". Responda apenas com a classificação, sem adicionar comentários ou explicações adicionais.
"""

# Define função para exibição da classificação
def add_emoji_to_classification(classification):
  if classification == "Positivo":
    return "😊 " + classification
  elif classification == "Neutro":
    return "😐 " + classification
  elif classification == "Negativo":
    return "😞 " + classification
  else:
    return classification

# Define função para comparação com resultado da coluna "sentiment"
def compare_classification_with_actual(classification, actual_sentiment):
  is_correct = classification.lower() == actual_sentiment.lower()
  result = "✅ Correto" if is_correct else "❌ Incorreto"
  return result, is_correct

# %% [markdown]
# ## 6.1 Using OpenAI (GPT-4o)

# %%
# !pip install -qU langchain-openai

# %%
import os
from google.colab import userdata

# %%
from google.colab import userdata
from langchain_openai import ChatOpenAI

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

llm = ChatOpenAI(
    model_name="gpt-4o",
    temperature=0
)

def classify_with_openai(review_text):
    prompt = prompt_template.format(review_text=review_text)

    response = llm.predict(prompt)
    return response.strip()

random_reviews = df.sample(n=10)

print("Classificação da OpenAI GPT-4")
print("=" * 90)

for index, row in random_reviews.iterrows():
    review_text = row['review']
    classification = classify_with_openai(review_text)
    display_classification = add_emoji_to_classification(classification)
    result, is_correct = compare_classification_with_actual(classification, row['sentiment'])

    print(f"\nAvaliação: {review_text}")
    print(f"Classificação da OpenAI: {display_classification}")
    print("-" * 90)
    print(f"Sentimento Real: {row['sentiment'].capitalize()}")
    print(f"Resultado: {result}")
# Out:
# Classificação da OpenAI GPT-4
# ==========================================================================================
#
# Avaliação: O touch é muito responsivo, funciona sem falhas.
# Classificação da OpenAI: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto
#
# Avaliação: O celular é ideal para gamers, com ótima performance gráfica.
# Classificação da OpenAI: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto
#
# Avaliação: Caiu no chão e quebrou no primeiro dia! Muito frágil!
# Classificação da OpenAI: 😞 Negativo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Negativo
# Resultado: ✅ Correto
#
# Avaliação: Comprei apenas porque tava barato, mas me surpreendi positivamente!
# Classificação da OpenAI: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto
#
# Avaliação: Tive uma experiência ruim porque o preço é muito alto para o que oferece.
# Classificação da OpenAI: 😞 Negativo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Negativo
# Resultado: ✅ Correto
#
# Avaliação: O suporte foi rápido e eficiente, gostei muito.
# Classificação da OpenAI: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto
#
# Avaliação: Chegou amassado, mas o produto funciona normalmente.
# Classificação da OpenAI: 😐 Neutro
# ------------------------------------------------------------------------------------------
# Sentimento Real: Neutro
# Resultado: ✅ Correto
#
# Avaliação: O suporte foi lento, mas resolveu meu problema.
# Classificação da OpenAI: 😐 Neutro
# ------------------------------------------------------------------------------------------
# Sentimento Real: Neutro
# Resultado: ✅ Correto
#
# Avaliação: A câmera frontal tem bons recursos, mas o foco automático é lento.
# Classificação da OpenAI: 😐 Neutro
# ------------------------------------------------------------------------------------------
# Sentimento Real: Neutro
# Resultado: ✅ Correto
#
# Avaliação: Gostei muito porque a qualidade é excelente.
# Classificação da OpenAI: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto

# %% [markdown]
# ## 6.2 Using Google Gemini 1.5

# %%
from google.colab import userdata
import google.generativeai as genai

# Retorna a chave de API do Google Gemini do userdata
myKey = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=myKey)

# Espcifica o modelo do Gemini
model = genai.GenerativeModel("gemini-1.5-flash-latest")

def classify_with_gemini(review_text):
    response = model.generate_content(prompt_template.format(review_text=review_text))
    classification = response.text.strip()
    return classification

# Classifica 10 reviews aleatórias
random_reviews = df.sample(n=10)

print("Classificação do Google Gemini 1.5")
print("=" * 90)

for index, row in random_reviews.iterrows():
    review_text = row['review']
    classification = classify_with_gemini(review_text)

    # Adiciona o emoji
    display_classification = add_emoji_to_classification(classification)

    # Compara o resultado com o sentimento correto
    result, is_correct = compare_classification_with_actual(classification, row['sentiment'])

    print(f"\nAvaliação: {review_text}")
    print(f"Classificação do Gemini: {display_classification}")
    print("-" * 90)
    print(f"Sentimento Real: {row['sentiment'].capitalize()}")
    print(f"Resultado: {result}")
# Out:
# Classificação do Google Gemini 1.5
# ==========================================================================================
#
# Avaliação: O desempenho do produto é mediano, esperava mais.
# Classificação do Gemini: 😞 Negativo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Neutro
# Resultado: ❌ Incorreto
#
# Avaliação: Demorou 20 dias pra chegar, e quando abri a caixa, estava quebrado!
# Classificação do Gemini: 😞 Negativo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Negativo
# Resultado: ✅ Correto
#
# Avaliação: Chegou com atraso, mas o produto é excelente.
# Classificação do Gemini: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto
#
# Avaliação: Recebi antes do prazo e o produto é excelente.
# Classificação do Gemini: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto
#
# Avaliação: Vi gente reclamando, mas pra ser sincero, eu gostei bastante!
# Classificação do Gemini: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto
#
# Avaliação: Chegou danificado e o suporte foi ineficiente.
# Classificação do Gemini: 😞 Negativo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Negativo
# Resultado: ✅ Correto
#
# Avaliação: O aparelho é resistente, mas a traseira risca facilmente.
# Classificação do Gemini: 😞 Negativo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Neutro
# Resultado: ❌ Incorreto
#
# Avaliação: Não tenho muito o que comentar, não é nada especial.
# Classificação do Gemini: 😐 Neutro
# ------------------------------------------------------------------------------------------
# Sentimento Real: Neutro
# Resultado: ✅ Correto
#
# Avaliação: Não funciona como esperado, uma decepção total.
# Classificação do Gemini: 😞 Negativo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Negativo
# Resultado: ✅ Correto
#
# Avaliação: Chegou com um pequeno atraso, mas estou satisfeito com o resultado.
# Classificação do Gemini: 😊 Positivo
# ------------------------------------------------------------------------------------------
# Sentimento Real: Positivo
# Resultado: ✅ Correto
